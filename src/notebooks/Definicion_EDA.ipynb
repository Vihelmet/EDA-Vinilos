# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# #### **EVOLUCIÓN DE LOS FORMATOS DE CONSUMO MUSICAL A LO LARGO DE LOS AÑOS Y EFECTO EN SU CUOTA DE MERCADO**

# %% [markdown]
# ### TEMA

# %% [markdown]
# ##### Estudio de las tendencias de consumo musical en función de su formato y si esas tendencias quedan reflejadas en las cifras de mercado.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# 1. La venta de vinilos no ha sufrido cambios fundamentales en función de las modas.
# 2. Los formatos de consumo de música han variado de manera significativa a lo largo de los años
# y de la aparición de las tecnologías.
# 3. A pesar de los cambios de formato, el público amante del vinilo se mantiene fiel a pesar de las tendencias.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
import numpy as np

df_1 = pd.read_csv(r"C:\Users\vsuar\Documents\THE BRIDGE\EDA\BBDD\release_data.csv")
df_1
# Out:
#           release_id         country    year       genre format
# 0                  1          Sweden  1999.0  Electronic  Vinyl
# 1                  2          Sweden  1998.0  Electronic  Vinyl
# 2                  3              US  1999.0  Electronic     CD
# 3                  4              US  1999.0  Electronic     CD
# 4                  5         Germany  1995.0  Electronic     CD
# ...              ...             ...     ...         ...    ...
# 17372030    15731745            Peru  1980.0         Pop  Vinyl
# 17372031    15731748          Mexico  1975.0       Latin  Vinyl
# 17372032    15731752  Czech Republic  2020.0  Electronic  Vinyl
# 17372033    15731758          Canada  2007.0  Electronic  Vinyl
# 17372034    15731760        Colombia  2006.0       Latin     CD
#
# [17372035 rows x 5 columns]

# %%
df_1['year'].min()
# Out:
# 1860.0

# %%
df_1['year'].max()
# Out:
# 2021.0

# %%
df_2 = pd.read_csv(r"C:\Users\vsuar\Documents\THE BRIDGE\EDA\BBDD\mikemillford-collection-20230514-0116.csv")
df_2
# Out:
#                 Catalog#                                        Artist  \
# 0                  T-539                      The Alan Parsons Project
# 1                  4M501                                    Television
# 2              9 45576-2                                Dead Can Dance
# 3                 ad 903                                Throwing Muses
# 4               BAD 0014                                        Pixies
# ...                  ...                                           ...
# 1567     ZN-401 E, 54668                            Joan Manuel Serrat
# 1568               ZTZ 3                                Crossbones (7)
# 1569           ZdeO 10/a                                       Various
# 1570  ZTT IQ1, XD-302419                     Frankie Goes To Hollywood
# 1571          CM 03223-4  Dmitri Shostakovich / Borodin String Quartet
#
#                                                   Title                 Label  \
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
df_1.head()
# Out:
#    release_id  country    year       genre format
# 0           1   Sweden  1999.0  Electronic  Vinyl
# 1           2   Sweden  1998.0  Electronic  Vinyl
# 2           3       US  1999.0  Electronic     CD
# 3           4       US  1999.0  Electronic     CD
# 4           5  Germany  1995.0  Electronic     CD

# %%
df_2.head()
# Out:
#     Catalog#                    Artist  \
# 0      T-539  The Alan Parsons Project
# 1      4M501                Television
# 2  9 45576-2            Dead Can Dance
# 3     ad 903            Throwing Muses
# 4   BAD 0014                    Pixies
#
#                                                Title                 Label  \
# 0  Tales Of Mystery And Imagination - Edgar Allan...  20th Century Records
# 1                                       Marquee Moon     4 Men With Beards
# 2                                  The Serpent's Egg                   4AD
# 3                                              Dizzy                   4AD
# 4                                       Dig For Fire                   4AD
#
#                Format  Rating  Released  release_id CollectionFolder  \
# 0       LP, Album, RE     NaN      1977     7823579      12 Pulgadas
# 1  LP, Album, RE, 180     NaN      2003    12147843      12 Pulgadas
# ...
